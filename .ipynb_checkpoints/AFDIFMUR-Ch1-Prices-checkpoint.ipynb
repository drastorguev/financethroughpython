# %%
import pandas_datareader.data as web
import pandas as pd
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
start = datetime.datetime(2010, 12, 31)
end = datetime.datetime(2013, 12, 31)
amzn = web.DataReader("AMZN", 'yahoo', start, end)
amzn.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2013-12-24  402.519989  403.720001  396.369995  399.200012  399.200012
# 2013-12-26  401.790009  404.519989  396.809998  404.390015  404.390015
# 2013-12-27  404.649994  405.630005  396.250000  398.079987  398.079987
# 2013-12-30  399.410004  399.920013  392.450012  393.369995  393.369995
# 2013-12-31  394.579987  398.829987  393.799988  398.790009  398.790009
#
#              Volume
# Date
# 2013-12-24  1380400
# 2013-12-26  1868500
# 2013-12-27  1986900
# 2013-12-30  2487100
# 2013-12-31  1996500

# %%
amzn.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31  181.960007  182.300003  179.509995  180.000000  180.000000
# 2011-01-03  181.369995  186.000000  181.210007  184.220001  184.220001
# 2011-01-04  186.149994  187.699997  183.779999  185.009995  185.009995
# 2011-01-05  184.100006  187.449997  184.070007  187.419998  187.419998
# 2011-01-06  186.500000  187.410004  185.250000  185.860001  185.860001
#
#              Volume
# Date
# 2010-12-31  3451900
# 2011-01-03  5331400
# 2011-01-04  5031800
# 2011-01-05  3418800
# 2011-01-06  3179700

# %% [markdown]
# Although the order of data is different, both tables above correspond to Figure 1.1 on page 4.

# %%
type(amzn.index[0])
# Out:
# pandas._libs.tslib.Timestamp

# %% [markdown]
# Index already has been converted to a Timestamp type of data series.

# %%
amzn.columns = ['AMZN.Open','AMZN.High','AMZN.Low', 'AMZN.Close','AMZN.Adjusted','AMZN.Volume']

# %%
amzn.head()
# Out:
#              AMZN.Open   AMZN.High    AMZN.Low  AMZN.Close  AMZN.Adjusted  \
# Date
# 2010-12-31  181.960007  182.300003  179.509995  180.000000     180.000000
# 2011-01-03  181.369995  186.000000  181.210007  184.220001     184.220001
# 2011-01-04  186.149994  187.699997  183.779999  185.009995     185.009995
# 2011-01-05  184.100006  187.449997  184.070007  187.419998     187.419998
# 2011-01-06  186.500000  187.410004  185.250000  185.860001     185.860001
#
#             AMZN.Volume
# Date
# 2010-12-31      3451900
# 2011-01-03      5331400
# 2011-01-04      5031800
# 2011-01-05      3418800
# 2011-01-06      3179700

# %% [markdown]
# Names of columns have been updated as on page 11.

# %%
amzn['AMZN.Close'].plot(figsize=(15,15), grid=True)

# %% [markdown]
# Similar plot to Figure 1.2 on page 13.

# %%
amznmissing = amzn.drop(amzn.index[400:500])
amznmissing['AMZN.Close'].plot(figsize=(15,15), grid=True)

# %% [markdown]
# Similar plot to Figure 1.3 on page 14, after rows between 400 and 500 being removed.

# %%
amzn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 755 entries, 2010-12-31 to 2013-12-31
# Data columns (total 6 columns):
# AMZN.Open        755 non-null float64
# AMZN.High        755 non-null float64
# AMZN.Low         755 non-null float64
# AMZN.Close       755 non-null float64
# AMZN.Adjusted    755 non-null float64
# AMZN.Volume      755 non-null int64
# dtypes: float64(5), int64(1)
# memory usage: 61.3 KB

# %%
amzn.describe()
# Out:
#         AMZN.Open   AMZN.High    AMZN.Low  AMZN.Close  AMZN.Adjusted  \
# count  755.000000  755.000000  755.000000  755.000000     755.000000
# mean   238.158953  240.997589  235.237549  238.306252     238.306252
# std     53.059365   53.276952   52.736751   53.071766      53.071766
# min    161.190002  163.539993  160.589996  160.970001     160.970001
# 25%    192.839996  195.400002  190.214996  193.295006     193.295006
# 50%    226.589996  230.679993  224.600006  227.350006     227.350006
# 75%    266.714996  269.440002  263.775009  266.449997     266.449997
# max    404.649994  405.630005  399.200012  404.390015     404.390015
#
#         AMZN.Volume
# count  7.550000e+02
# mean   4.319524e+06
# std    2.628702e+06
# min    9.844000e+05
# 25%    2.660750e+06
# 50%    3.706200e+06
# 75%    5.160950e+06
# max    2.413420e+07

# %% [markdown]
# Similar to output on page 15.

# %% [markdown]
# Operations similar to the ones on pages between 16 and 25 can be found in pandas' documentation here: https://pandas.pydata.org/pandas-docs/stable/indexing.html

# %% [markdown]
# At the moment, unable to replicate output as on page 26. The code in comments comes relatively close, but the calculcations for some of the columns are incorrect.

# %%
# weekly = amzn.to_period('W')
# weekly.head()

# %% [markdown]
# At the moment, unable to replicate output for the candlesticks chart as on page 28. First need to sort out "Monthly Sampling" issue menntioned above.

# %%
amzn2 = web.DataReader("AMZN", 'yahoo', start, end)
amzn2.columns = ['AMZN.Open','AMZN.High','AMZN.Low', 'AMZN.Close','AMZN.Adjusted','AMZN.Volume']
amzn2.head()
# Out:
#              AMZN.Open   AMZN.High    AMZN.Low  AMZN.Close  AMZN.Adjusted  \
# Date
# 2010-12-31  181.960007  182.300003  179.509995  180.000000     180.000000
# 2011-01-03  181.369995  186.000000  181.210007  184.220001     184.220001
# 2011-01-04  186.149994  187.699997  183.779999  185.009995     185.009995
# 2011-01-05  184.100006  187.449997  184.070007  187.419998     187.419998
# 2011-01-06  186.500000  187.410004  185.250000  185.860001     185.860001
#
#             AMZN.Volume
# Date
# 2010-12-31      3451900
# 2011-01-03      5331400
# 2011-01-04      5031800
# 2011-01-05      3418800
# 2011-01-06      3179700

# %%
# NO YAHOO DATA ATM :(

# yhoo2 = web.DataReader("YHOO", 'yahoo', start, end)
# yhoo2.columns = ['YHQ.Open','YHQ.High','YHQ.Low', 'YHQ.Close','YHQ.Adjusted','YHQ.Volume']
# yhoo2.head()

# %%
ibm2 = web.DataReader("IBM", 'yahoo', start, end)
ibm2.columns = ['IBM.Open','IBM.High','IBM.Low', 'IBM.Close','IBM.Adjusted','IBM.Volume']
ibm2.head()
# Out:
#               IBM.Open    IBM.High     IBM.Low   IBM.Close  IBM.Adjusted  \
# Date
# 2010-12-31  146.729996  147.070007  145.960007  146.759995    122.063370
# 2011-01-03  147.210007  148.199997  147.139999  147.479996    122.662216
# 2011-01-04  147.559998  148.220001  146.639999  147.639999    122.795311
# 2011-01-05  147.339996  147.479996  146.729996  147.050003    122.304588
# 2011-01-06  147.130005  148.789993  146.820007  148.660004    123.643654
#
#             IBM.Volume
# Date
# 2010-12-31     2969800
# 2011-01-03     4603800
# 2011-01-04     5060100
# 2011-01-05     4657400
# 2011-01-06     5029200

# %%
gspc2 = web.DataReader("^GSPC", 'yahoo', start, end)
gspc2.columns = ['GSPC.Open','GSPC.High','GSPC.Low', 'GSPC.Close','GSPC.Adjusted','GSPC.Volume']
gspc2.head()
# Out:
#               GSPC.Open    GSPC.High     GSPC.Low   GSPC.Close  GSPC.Adjusted  \
# Date
# 2010-12-31  1256.760010  1259.339966  1254.189941  1257.640015    1257.640015
# 2011-01-03  1257.619995  1276.170044  1257.619995  1271.869995    1271.869995
# 2011-01-04  1272.949951  1274.119995  1262.660034  1270.199951    1270.199951
# 2011-01-05  1268.780029  1277.630005  1265.359985  1276.560059    1276.560059
# 2011-01-06  1276.290039  1278.170044  1270.430054  1273.849976    1273.849976
#
#             GSPC.Volume
# Date
# 2010-12-31   1799770000
# 2011-01-03   4286670000
# 2011-01-04   4796420000
# 2011-01-05   4764920000
# 2011-01-06   4844100000

# %%
closeprice = pd.concat([gspc2['GSPC.Close'],amzn2['AMZN.Close'],ibm2['IBM.Close']], axis=1, join='outer')

# %%
closeprice.head()
# Out:
#              GSPC.Close  AMZN.Close   IBM.Close
# Date
# 2010-12-31  1257.640015  180.000000  146.759995
# 2011-01-03  1271.869995  184.220001  147.479996
# 2011-01-04  1270.199951  185.009995  147.639999
# 2011-01-05  1276.560059  187.419998  147.050003
# 2011-01-06  1273.849976  185.860001  148.660004

# %% [markdown]
# The table above is identical to the output on page 32.

# %%
closeprice['GSPC.idx'] = closeprice['GSPC.Close'] / closeprice['GSPC.Close'][0]
closeprice['AMZN.idx'] = closeprice['AMZN.Close'] / closeprice['AMZN.Close'][0]
closeprice['IBM.idx'] = closeprice['IBM.Close'] / closeprice['IBM.Close'][0]
closeprice.head()
# Out:
#              GSPC.Close  AMZN.Close   IBM.Close  GSPC.idx  AMZN.idx   IBM.idx
# Date
# 2010-12-31  1257.640015  180.000000  146.759995  1.000000  1.000000  1.000000
# 2011-01-03  1271.869995  184.220001  147.479996  1.011315  1.023444  1.004906
# 2011-01-04  1270.199951  185.009995  147.639999  1.009987  1.027833  1.005996
# 2011-01-05  1276.560059  187.419998  147.050003  1.015044  1.041222  1.001976
# 2011-01-06  1273.849976  185.860001  148.660004  1.012889  1.032556  1.012946

# %% [markdown]
# The table above is identical to the output on page 33.

# %%
closeprice[['GSPC.idx','AMZN.idx','IBM.idx']].plot(figsize=(15,15), grid=True, linestyle='--')

# %% [markdown]
# Ignoring additional styling features, the chart above is very similar to the one in Figure 1.5 on page 37.

# %% [markdown]
# <div style='color:red'> TO CONTINUE WORK ON PAGE 38</div>
